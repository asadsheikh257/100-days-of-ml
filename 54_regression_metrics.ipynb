# %% [markdown]
# # **Regression Metrics MAE, MSE, RMSE, R2, Adjusted R2**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./dataset/placement01.csv')

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')  
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print('mean_absolute_error:', mean_absolute_error(y_test, y_pred))
# Out:
# mean_absolute_error: 0.25524334486204076

# %%
print('mean_squared_error:', mean_squared_error(y_test, y_pred))
# Out:
# mean_squared_error: 0.10221131059334207

# %%
print('rmse', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# rmse 0.31970503685951224

# %%
print('r2_score:', r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# r2_score: 0.7297167943957027

# %%
X_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7714771649771606

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa', 'random_feature', 'package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.685204     3.26
# 1  5.12        0.776942     1.98
# 2  7.82        0.154992     3.25
# 3  7.42        0.528433     3.67
# 4  6.94        0.894348     3.57

# %%
plt.scatter(new_df1['random_feature'], new_df1['package'])
plt.xlabel('Random Feature')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2, test_size=0.2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print('R2 Score', r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 Score 0.7773367248495411

# %%
# adjusted r2
1 - (1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)
# Out:
# 0.7653008721387055

# %%
X_test.shape
# Out:
# (40, 2)

# %% [markdown]
# # **Bagging vs Random Forest**

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -1.545517 -0.870383 -1.745835  4.629456 -0.830510       0
# 1  0.794650  0.525421  0.159923 -1.128419 -0.380999       1
# 2  1.172076 -1.250173  0.031167 -0.619607 -3.185327       0
# 3  2.990956 -0.240509 -0.513291 -1.184511 -0.166749       0
# 4  0.149965 -1.368935 -0.496767  1.490141 -1.901350       0

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:, :5], df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:, :5], df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features=2, random_state=277367001),
#  DecisionTreeClassifier(max_features=2, random_state=1855867751),
#  DecisionTreeClassifier(max_features=2, random_state=1097182489),
#  DecisionTreeClassifier(max_features=2, random_state=221293324),
#  DecisionTreeClassifier(max_features=2, random_state=715392994),
#  DecisionTreeClassifier(max_features=2, random_state=462855140),
#  DecisionTreeClassifier(max_features=2, random_state=997763221),
#  DecisionTreeClassifier(max_features=2, random_state=68166446),
#  DecisionTreeClassifier(max_features=2, random_state=1581724253),
#  DecisionTreeClassifier(max_features=2, random_state=1475876760),
#  DecisionTreeClassifier(max_features=2, random_state=504825407),
#  DecisionTreeClassifier(max_features=2, random_state=685356315),
#  DecisionTreeClassifier(max_features=2, random_state=1348982289),
#  DecisionTreeClassifier(max_features=2, random_state=1457335302),
#  DecisionTreeClassifier(max_features=2, random_state=1649192233),
#  DecisionTreeClassifier(max_features=2, random_state=366222497),
#  DecisionTreeClassifier(max_features=2, random_state=723812999),
#  DecisionTreeClassifier(max_features=2, random_state=726953211),
#  DecisionTreeClassifier(max_features=2, random_state=347073178),
#  DecisionTreeClassifier(max_features=2, random_state=1614767600),
#  DecisionTreeClassifier(max_features=2, random_state=241767969),
#  DecisionTreeClassifier(max_features=2, random_state=707103722),
#  DecisionTreeClassifier(max_features=2, random_state=1261150986),
#  DecisionTreeClassifier(max_features=2, random_state=2019889918),
#  DecisionTreeClassifier(max_features=2, random_state=883370722),
#  DecisionTreeClassifier(max_features=2, random_state=2087809903),
#  DecisionTreeClassifier(max_features=2, random_state=801688783),
#  DecisionTreeClassifier(max_features=2, random_state=2031665111),
#  DecisionTreeClassifier(max_features=2, random_state=1050465710),
#  DecisionTreeClassifier(max_features=2, random_state=714842375),
#  DecisionTreeClassifier(max_features=2, random_state=710370192),
#  DecisionTreeClassifier(max_features=2, random_state=287841782),
#  DecisionTreeClassifier(max_features=2, random_state=1530793555),
#  DecisionTreeClassifier(max_features=2, random_state=1612926330),
#  DecisionTreeClassifier(max_features=2, random_state=1571140388),
#  DecisionTreeClassifier(max_features=2, random_state=1117524710),
#  DecisionTreeClassifier(max_features=2, random_state=194583691),
#  DecisionTreeClassifier(max_features=2, random_state=1956347371),
#  DecisionTreeClassifier(max_features=2, random_state=158132599),
#  DecisionTreeClassifier(max_features=2, random_state=1008992343),
#  DecisionTreeClassifier(max_features=2, random_state=1773195096),
#  DecisionTreeClassifier(max_features=2, random_state=1168364481),
#  DecisionTreeClassifier(max_features=2, random_state=1501242169),
#  DecisionTreeClassifier(max_features=2, random_state=748250395),
#  DecisionTreeClassifier(max_features=2, random_state=59968878),
#  DecisionTreeClassifier(max_features=2, random_state=328473029),
#  DecisionTreeClassifier(max_features=2, random_state=1468342032),
#  DecisionTreeClassifier(max_features=2, random_state=1634623714),
#  DecisionTreeClassifier(max_features=2, random_state=2027266029),
#  DecisionTreeClassifier(max_features=2, random_state=485722463),
#  DecisionTreeClassifier(max_features=2, random_state=1392491102),
#  DecisionTreeClassifier(max_features=2, random_state=2074295702),
#  DecisionTreeClassifier(max_features=2, random_state=1272927860),
#  DecisionTreeClassifier(max_features=2, random_state=248806918),
#  DecisionTreeClassifier(max_features=2, random_state=329702126),
#  DecisionTreeClassifier(max_features=2, random_state=1605450979),
#  DecisionTreeClassifier(max_features=2, random_state=1756034379),
#  DecisionTreeClassifier(max_features=2, random_state=1141274167),
#  DecisionTreeClassifier(max_features=2, random_state=1934532749),
#  DecisionTreeClassifier(max_features=2, random_state=1633731551),
#  DecisionTreeClassifier(max_features=2, random_state=933071577),
#  DecisionTreeClassifier(max_features=2, random_state=918131624),
#  DecisionTreeClassifier(max_features=2, random_state=553775111),
#  DecisionTreeClassifier(max_features=2, random_state=514443238),
#  DecisionTreeClassifier(max_features=2, random_state=913623445),
#  DecisionTreeClassifier(max_features=2, random_state=659948683),
#  DecisionTreeClassifier(max_features=2, random_state=125251397),
#  DecisionTreeClassifier(max_features=2, random_state=1154250657),
#  DecisionTreeClassifier(max_features=2, random_state=1439653555),
#  DecisionTreeClassifier(max_features=2, random_state=548201498),
#  DecisionTreeClassifier(max_features=2, random_state=726485310),
#  DecisionTreeClassifier(max_features=2, random_state=1966736951),
#  DecisionTreeClassifier(max_features=2, random_state=800318878),
#  DecisionTreeClassifier(max_features=2, random_state=2067884456),
#  DecisionTreeClassifier(max_features=2, random_state=1066293162),
#  DecisionTreeClassifier(max_features=2, random_state=596945201),
#  DecisionTreeClassifier(max_features=2, random_state=2141953604),
#  DecisionTreeClassifier(max_features=2, random_state=1193663006),
#  DecisionTreeClassifier(max_features=2, random_state=1853719045),
#  DecisionTreeClassifier(max_features=2, random_state=285278758),
#  DecisionTreeClassifier(max_features=2, random_state=1690973918),
#  DecisionTreeClassifier(max_features=2, random_state=1064189736),
#  DecisionTreeClassifier(max_features=2, random_state=36060292),
#  DecisionTreeClassifier(max_features=2, random_state=328738779),
#  DecisionTreeClassifier(max_features=2, random_state=1699942727),
#  DecisionTreeClassifier(max_features=2, random_state=1384445598),
#  DecisionTreeClassifier(max_features=2, random_state=564601125),
#  DecisionTreeClassifier(max_features=2, random_state=751465422),
#  DecisionTreeClassifier(max_features=2, random_state=1578801830),
#  DecisionTreeClassifier(max_features=2, random_state=1481487726),
#  DecisionTreeClassifier(max_features=2, random_state=336790253),
#  DecisionTreeClassifier(max_features=2, random_state=1228842641),
#  DecisionTreeClassifier(max_features=2, random_state=1046749655),
#  DecisionTreeClassifier(max_features=2, random_state=1598122222),
#  DecisionTreeClassifier(max_features=2, random_state=263421216),
#  DecisionTreeClassifier(max_features=2, random_state=388677174),
#  DecisionTreeClassifier(max_features=2, random_state=1868298781),
#  DecisionTreeClassifier(max_features=2, random_state=1423539977),
#  DecisionTreeClassifier(max_features=2, random_state=1144231749),
#  DecisionTreeClassifier(max_features=2, random_state=1718226749)]

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
